// %% [markdown]
// # Play with opencv

// %%
#include "init.opencv.cpp" // See file init.opencv.cpp

// %%
cv::Mat lena = cv::imread("lena.jpg");

// %% [markdown]
// im::show() function is defined in [init.opencv.cpp](init.opencv.cpp)

// %%
im::show(lena)

// %%
cv::Mat blur;
cv::blur(lena, blur, cv::Size(15, 15));
im::show(blur)

// %%
%%timeit
cv::resize(lena, blur, cv::Size(1500, 1500), cv::INTER_LANCZOS4);
// Out:
// input_line_68:7:1: error: no matching conversion for functional-style cast from 'typename common_type<duration<long, ratio<1, 1000000000> >, duration<long, ratio<1, 1000000000> > >::type'
//       (aka 'std::chrono::duration<long, std::ratio<1, 1000000000> >') to 'std::chrono::duration<double>'
// std::chrono::duration<double>(_t1-_t0).count();
// ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /usr/include/c++/7/chrono:319:2: note: candidate constructor not viable: no known conversion from 'duration<long, ratio<[...], 1000000000>>' to 'const duration<double, ratio<[...], 1>>' for
//       1st argument
//         duration(const duration&) = default;
//         ^
// /usr/include/c++/7/chrono:327:23: note: candidate template ignored: substitution failure [with _Rep2 = std::chrono::duration<long, std::ratio<1, 1000000000> >]: no member named 'value' in
//       'std::is_convertible<const std::chrono::duration<long, std::ratio<1, 1000000000> > &, double>'
// ...
